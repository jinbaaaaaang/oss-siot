# %% [markdown]
# <a href="https://colab.research.google.com/github/jinbaaaaaang/siot/blob/main/train_koGPT2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets torch accelerate scikit-learn

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/jinbaaaaaang/siot.git
# Out:
# Cloning into 'siot'...
# remote: Enumerating objects: 329, done.
# remote: Counting objects: 100% (329/329), done.
# remote: Compressing objects: 100% (237/237), done.
# remote: Total 329 (delta 154), reused 237 (delta 79), pack-reused 0 (from 0)
# Receiving objects: 100% (329/329), 8.35 MiB | 16.96 MiB/s, done.
# Resolving deltas: 100% (154/154), done.

# %%
# %cd /content/siot/backend
# Out:
# /content/siot/backend

# %%
exec(open('train_kogpt2_colab.py').read())
# Out:
# ...
# Google Colab에서 koGPT2 모델 k-fold 교차 검증 학습
# ...
#
# ✅ GPU 사용 가능: Tesla T4
# 💡 GPU 모드로 학습을 진행합니다.
#    CUDA 오류가 발생하면 런타임을 재시작하세요: 런타임 → 런타임 다시 시작
#
# ...
# [KPoeM 데이터셋 다운로드]
#   - 소스: Hugging Face (AKS-DHLAB/KPoEM)
#   - 최대 개수: 100
# ...
#
# [다운로드 시도] AKS-DHLAB/KPoEM...
# ✅ 데이터셋 로드 성공: 615개 샘플
# ✅ 100개 데이터 변환 완료
#
# ...
# [k-fold 교차 검증 시작]
#   - 데이터 개수: 100
#   - Fold 개수: 5
# ...
#
# ✅ GPU 사용 가능 (디바이스 1개 감지)
# 💡 GPU 모드로 학습을 진행합니다.
#
# ...
# [Fold 1/5]
#   - Train: 80개
#   - Test: 20개
# ...
#
#
# ...
# [koGPT2 모델 학습 시작]
#   - 학습 데이터: 80개
#   - Epochs: 2
#   - Learning Rate: 5e-05
#   - Batch Size: 4
#   - Gradient Accumulation Steps: 4
# ...
#
# [1/5] 모델 및 토크나이저 로딩: skt/kogpt2-base-v2
#   - 초기 vocab 크기: 51201 (base: 51200)
#   ⚠️ 토크나이저 로드 시 이미 추가 토큰 1개가 포함되어 있습니다.
#   🔧 토크나이저를 base_vocab_size에 맞춰 조정합니다...
#   - Base vocab size: 51200
#   - Actual vocab size (len(tokenizer)): 51201
#   - Pad token ID: 51200
#   - EOS token ID: 51200
#   ⚠️ 추가 토큰: 1개 (모델 리사이즈 필요)
#   - 디바이스: CUDA
#   - GPU 이름: Tesla T4
#   - GPU 메모리: 14.7GB
# ...

# %%
pip install bert-score

# %%
exec(open('evaluate_folds_colab.py').read())
# Out:
# ...
# k-fold 모델 성능 평가
# ...
#
# ✅ GPU 사용: Tesla T4
#
# [0/4] 모델 폴더 찾기...
# ⚠️ ./kogpt2_finetuned 폴더를 찾을 수 없습니다. 자동 검색 중...
#
# 📁 찾은 폴더:
#   1. kogpt2_finetuned_fold2_20251205_101423
#   2. kogpt2_finetuned_fold5_20251205_102339
#   3. kogpt2_finetuned_fold4_20251205_102222
#   4. kogpt2_finetuned_fold1_20251205_101934
#   5. kogpt2_finetuned_fold4_20251205_101637
#   6. kogpt2_finetuned_fold3_20251205_101530
#   7. kogpt2_finetuned_fold2_20251205_102023
#   8. kogpt2_finetuned_fold3_20251205_102127
#   9. kogpt2_finetuned_fold5_20251205_101732
#   10. kogpt2_finetuned_fold1_20251205_101320
#
# 💡 여러 폴더를 찾았습니다. 첫 번째 폴더를 사용합니다.
# ✅ 선택: kogpt2_finetuned_fold2_20251205_101423
# ✅ 모델 폴더: /content/siot/backend/kogpt2_finetuned_fold2_20251205_101423
#
# [1/4] 데이터 로드 중...
#
# ...
# [KPoeM 데이터셋 다운로드]
#   - 최대 개수: 100
# ...
#
# ✅ 100개 데이터 로드 완료
#
# [2/4] k-fold 분할 중...
#
# 🔍 Fold 모델 검색 중...
# ✅ 5개의 fold 모델을 찾았습니다:
#   - Fold 1: kogpt2_finetuned_fold1_20251205_101934
# ...
